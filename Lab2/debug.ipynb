# %%
import prepare_data

# %%
#Data - transform
import importlib
import data
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# %%
importlib.reload(data)
args= {'augment':'advanced'} # augment="advanced" in create_transforms()
train_ds = data.ImageFolderDataset(path='flowers_data/train',**args)
loader = DataLoader(train_ds,5,True)

# %%
train_features, train_labels = next(iter(loader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
img = train_features[0].squeeze()
img = img.reshape(224,224,3)
label = train_labels[0]
plt.imshow(img, cmap="gray")
plt.show()
print(f"Label: {label}")
# Out:
# Feature batch shape: torch.Size([5, 3, 224, 224])
# Labels batch shape: torch.Size([5])
# Label: 1
